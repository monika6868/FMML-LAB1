# %% [markdown]
# <a href="https://colab.research.google.com/github/monika6868/FMML-LAB1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-03 04:37:28--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   156MB/s    in 0.4s
#
# 2024-04-03 04:37:29 (156 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22079   1410.6791v4  We introduce the Locally Linear Latent Variabl...  stat
# 37361  1704.08716v1  Artificial intelligence methods have often bee...    cs
# 6795   1706.02524v2  Automating statistical modelling is a challeng...  stat
# 5160    1011.3090v2  Multiple kernel learning (MKL), structured spa...  stat
# 2127   1512.09204v1  We consider effort allocation in crowdsourcing...    cs
# ...             ...                                                ...   ...
# 23125  cs/0604062v1  Feature extraction and matching are among cent...    cs
# 32151  1604.03924v2  In this paper, we initiate a principled study ...    cs
# 22831  1708.01206v1  Recurrent major mood episodes and subsyndromal...  stat
# 22955  1711.08392v1  We present an efficient alternating direction ...  stat
# 3446   1705.02928v1  This paper addresses image classification thro...    cs
#
#                                                    title  year  \
# 22079  Bayesian Manifold Learning: The Locally Linear...  2014
# 37361     Artificial Intelligence Based Malware Analysis  2017
# 6795   Scaling up the Automatic Statistician: Scalabl...  2017
# 5160   Regularization Strategies and Empirical Bayesi...  2010
# 2127   Bayes-Optimal Effort Allocation in Crowdsourci...  2015
# ...                                                  ...   ...
# 23125  Biologically Inspired Hierarchical Model for F...  2006
# 32151  Max-Information, Differential Privacy, and Pos...  2016
# 22831  Detecting early signs of depressive and manic ...  2017
# 22955  An Efficient ADMM Algorithm for Structural Bre...  2017
# 3446   Cross-label Suppression: A Discriminative and ...  2017
#
#                                                 keywords
# 22079  [introduce, probabilistic, discovery, describe...
# 37361  [artificial, intelligence, functions, adversar...
# 6795   [automating, statistical, modelling, challengi...
# 5160   [structured, considerable, attention, differen...
# 2127   [allocation, crowdsourcing, imperfect, homogen...
# ...                                                  ...
# 23125  [extraction, inefficent, locations, neurophysi...
# 32151  [principled, generalization, properties, appro...
# 22831  [recurrent, subsyndromal, instability, substan...
# 22955  [efficient, alternating, direction, multiplier...
# 3446   [addresses, classification, discriminative, di...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22079    [introduce, probabilistic, discovery, describe...
# 37361    [artificial, intelligence, functions, adversar...
# 6795     [automating, statistical, modelling, challengi...
# 5160     [structured, considerable, attention, differen...
# 2127     [allocation, crowdsourcing, imperfect, homogen...
#                                ...
# 1570     [expressively, functions, inherently, successe...
# 35901    [incomplete, conflicting, narrative, knowledge...
# 22676    [shrinkage, selection, networkstructured, part...
# 3270     [motivated, unsupervised, construction, statis...
# 22430    [hierarchical, dirichlet, considers, dependenc...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8841 words.
# Out of those 4568 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="dd4fb101-2826-49b0-8a0b-226aaf051155" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd4fb101-2826-49b0-8a0b-226aaf051155")) {                    Plotly.newPlot(                        "dd4fb101-2826-49b0-8a0b-226aaf051155",                        [{"x":["conditioned","relationships","observation","probabilistic","hypothesised","preserving","intrinsic","construct","distribution","introduce","intuitions","additional","variational","neighbourhood","encapsulates","embedding","observations","straightforward","optimisation","coordinates","posterior","describes","dimensionality","extensions","structure","discovery","semantics","biologically","similarities","particular","hopefully","promising","techniques","information","sufficient","ecosystem","providing","functions","capability","piecemeal","development","characteristics","adversary","biological","artificial","difficult","intelligence","communities","attributed","sophistication","integration","understand","underlying","regression","significantly","employing","processes","automatic","likelihood","statistical","automating","composition","statistician","modelling","algorithm","selection","challenging","direction","interpretable","algorithms","understood","experiments","comparable","usefulness","generative","regularizer","represented","preferable","strategies","naturally","regularization","operation","considerable","combination","applications","attention","empirical","simplicity","different","numerical","systematically","conjugate","separable","structured","components","maximization","demonstrate","homogeneous","imperfect","relaxation","infeasible","continuous","crowdsourcing","multiarmed","computation","outperforms","lagrangian","partially","tractable","observable","technique","computationally","optimality","allocation","constraints","numerically","inference","evolution","uncovering","inferring","capabilities","multivariate","performance","linguistic","evidenced","demonstrating","discussions","arguments","interaction","influence","committee","discovers","transcripts","primarily","addresses","introducing","segmented","classification","parameters","sequences","challenge","convolutional","individual","evaluated","constructed","recognition","effectively","estimates","completion","differentially","filtering","furthermore","guarantees","differential","objective","violating","revisited","consistently","preference","preferences","collaborative","empirically","reconstruct","discovering","framework","superiority","attributes","established","comparisons","integrated","traditional","exploited","corresponding","clustering","illustrate","categorical","contribution","quantitative","maximizing","localizes","connected","supervised","parameter","localizing","propagation","classifiers","optimized","localization","classifier","searching","typically","efficient","arbitrary","concentrated","important","controlled","efficiently","projected","contributes","manifests"],"y":[18,63,57,151,2,47,57,65,227,326,5,114,52,8,3,111,71,24,25,12,42,86,41,39,347,53,96,12,39,284,2,125,391,671,70,4,95,218,55,2,121,96,16,53,119,142,98,18,12,1,54,65,126,107,272,20,102,170,72,158,10,23,0,59,786,164,268,50,33,596,37,581,85,26,99,10,80,5,89,62,87,41,47,149,440,171,146,20,759,91,21,9,13,106,108,31,530,24,9,18,11,121,12,1,188,260,7,45,37,22,276,91,25,27,127,11,207,60,3,27,30,21,885,63,3,41,12,24,90,65,4,8,1,19,60,53,26,478,254,101,135,366,123,147,63,388,104,74,35,6,78,166,71,33,154,2,9,35,28,29,36,71,36,29,529,45,61,47,31,62,159,27,113,153,80,10,62,62,16,3,71,184,134,12,64,110,62,61,145,22,119,382,99,15,381,28,164,21,15,4],"type":"bar"},{"x":["conditioned","relationships","observation","probabilistic","hypothesised","pres ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4568,), (4568, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7791666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Doubly</span> <span style=''>Robust</span> <span style=''>Policy</span> <span style='background-color:rgba(0, 255, 0, 0.408);'>Evaluation</span> <span style=''>and</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>decision</span> <span style=''>making</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.47572815533980584);'>environments</span> <span style=''>where</span> <span style=''>the</span> <span style=''>reward</span> <span style=''>is</span> <span style=''>only</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partially</span> <span style=''>observed</span> <span style=''>but</span> <span style=''>can</span> <span style=''>be</span> <span style=''>modeled</span> <span style=''>as</span> <span style=''>a</span> <span style=''>function</span> <span style=''>of</span> <span style=''>an</span> <span style=''>action</span> <span style=''>and</span> <span style=''>an</span> <span style=''>observed</span> <span style=''>context</span> <span style=''>This</span> <span style=''>setting</span> <span style=''>known</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.4642857142857143);'>contextual</span> <span style=''>bandits</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333334);'>encompasses</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>variety</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>health</span> <span style=''>care</span> <span style=''>policy</span> <span style=''>and</span> <span style=''>Internet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advertising</span> <span style=''>A</span> <span style=''>central</span> <span style=''>task</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.408);'>evaluation</span> <span style=''>of</span> <span style=''>a</span> <span style=''>new</span> <span style=''>policy</span> <span style=''>given</span> <span style=''>historic</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.5492957746478873);'>consisting</span> <span style=''>of</span> <span style=''>contexts</span> <span style=''>actions</span> <span style=''>and</span> <span style=''>received</span> <span style=''>rewards</span> <span style=''>The</span> <span style=''>key</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>challenge</span> <span style=''>is</span> <span style=''>that</span> <span style=''>the</span> <span style=''>past</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>does</span> <span style=''>not</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>faithfully</span> <span style='background-color:rgba(0, 255, 0, 0.33749999999999997);'>represent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>proportions</span> <span style=''>of</span> <span style=''>actions</span> <span style=''>taken</span> <span style=''>by</span> <span style=''>a</span> <span style=''>new</span> <span style=''>policy</span> <span style=''>Previous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>rely</span> <span style=''>either</span> <span style=''>on</span> <span style=''>models</span> <span style=''>of</span> <span style=''>rewards</span> <span style=''>or</span> <span style=''>models</span> <span style=''>of</span> <span style=''>the</span> <span style=''>past</span> <span style=''>policy</span> <span style=''>The</span> <span style=''>former</span> <span style=''>are</span> <span style=''>plagued</span> <span style=''>by</span> <span style=''>a</span> <span style=''>large</span> <span style=''>bias</span> <span style=''>whereas</span> <span style=''>the</span> <span style=''>latter</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>for</span> <span style=''>Sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Conditional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Precision</span> <span style=''>Matrices</span> <br/><br/><span style=''>Given</span> <span style=''>n</span> <span style=''>iid</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>of</span> <span style=''>a</span> <span style=''>random</span> <span style=''>vector</span> <span style=''>(XZ)</span> <span style=''>where</span> <span style=''>X</span> <span style=''>is</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>vector</span> <span style=''>and</span> <span style=''>Z</span> <span style=''>is</span> <span style=''>a</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>index</span> <span style=''>variable</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style=''>inverse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>matrix</span> <span style=''>Omega(z)</span> <span style=''>(E(X</span> <span style=''>EX</span> <span style=''>mid</span> <span style=''>Z)(X</span> <span style=''>EX</span> <span style=''>mid</span> <span style=''>Z)T</span> <span style=''>mid</span> <span style=''>Zz)</span> <span style=''>1</span> <span style=''>under</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>that</span> <span style=''>the</span> <span style=''>set</span> <span style=''>of</span> <span style=''>non</span> <span style=''>zero</span> <span style=''>elements</span> <span style=''>is</span> <span style=''>small</span> <span style=''>and</span> <span style=''>does</span> <span style=''>not</span> <span style=''>depend</span> <span style=''>on</span> <span style=''>the</span> <span style=''>index</span> <span style=''>variable</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>that</span> <span style=''>combines</span> <span style=''>the</span> <span style=''>ideas</span> <span style=''>of</span> <span style=''>the</span> <span style=''>local</span> <span style=''>constant</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>smoothing</span> <span style=''>and</span> <span style=''>the</span> <span style=''>group</span> <span style=''>Lasso</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style=''>inverse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>matrix</span> <span style=''>A</span> <span style=''>proximal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>smoothing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>used</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>our</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Stability</span> <span style=''>Analysis</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.45038167938931295);'>Regularized</span> <span style=''>Least</span> <span style=''>Squares</span> <span style='background-color:rgba(255, 0, 0, 0.545647558386412);'>Regression</span> <br/><br/><span style=''>We</span> <span style=''>discuss</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stability</span> <span style=''>for</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>noisy</span> <span style=''>labels</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>are</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.545647558386412);'>regression</span> <span style=''>and</span> <span style=''>they</span> <span style=''>involve</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.45038167938931295);'>regularized</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.5384615384615384);'>functionals</span> <span style=''>such</span> <span style=''>as</span> <span style=''>L(f)</span> <span style=''>1N</span> <span style=''>sum</span> <span style=''>i</span> <span style=''>(f(x</span> <span style=''>i)</span> <span style=''>y</span> <span style=''>i)2</span> <span style=''>lambda</span> <span style=''>||f||</span> <span style=''>H2</span> <span style=''>We</span> <span style=''>shall</span> <span style=''>call</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>stable</span> <span style=''>if</span> <span style=''>when</span> <span style=''>y</span> <span style=''>i</span> <span style=''>is</span> <span style=''>a</span> <span style=''>noisy</span> <span style=''>version</span> <span style=''>of</span> <span style=''>f(x</span> <span style=''>i)</span> <span style=''>for</span> <span style=''>some</span> <span style=''>function</span> <span style=''>f</span> <span style=''>in</span> <span style=''>H</span> <span style=''>the</span> <span style=''>output</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(255, 0, 0, 0.3666666666666666);'>converges</span> <span style=''>to</span> <span style=''>f</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.32558139534883723);'>regularization</span> <span style=''>term</span> <span style=''>and</span> <span style=''>noise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style=''>vanish</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>two</span> <span style=''>flavors</span> <span style=''>of</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>one</span> <span style=''>where</span> <span style=''>a</span> <span style=''>data</span> <span style=''>set</span> <span style=''>of</span> <span style=''>N</span> <span style=''>points</span> <span style=''>remains</span> <span style=''>fixed</span> <span style=''>and</span> <span style=''>the</span> <span style=''>other</span> <span style=''>where</span> <span style=''>N</span> <span style=''>infinity</span> <span style=''>For</span> <span style=''>the</span> <span style=''>case</span> <span style=''>where</span> <span style=''>N</span> <span style=''>infinity</span> <span style=''>we</span> <span style=''>give</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Short</span> <span style=''>term</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Mortality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Prediction</span> <span style=''>for</span> <span style=''>Elderly</span> <span style=''>Patients</span> <span style=''>Using</span> <span style=''>Medicare</span> <span style=''>Claims</span> <span style=''>Data</span> <br/><br/><span style=''>Risk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>is</span> <span style=''>central</span> <span style=''>to</span> <span style=''>both</span> <span style=''>clinical</span> <span style=''>medicine</span> <span style=''>and</span> <span style=''>public</span> <span style=''>health</span> <span style=''>While</span> <span style=''>many</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>models</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>to</span> <span style=''>predict</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>mortality</span> <span style=''>they</span> <span style=''>are</span> <span style=''>rarely</span> <span style=''>applied</span> <span style=''>in</span> <span style=''>the</span> <span style=''>clinical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>where</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>tasks</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>typically</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>logistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>One</span> <span style=''>reason</span> <span style=''>for</span> <span style=''>this</span> <span style=''>is</span> <span style=''>that</span> <span style=''>existing</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>models</span> <span style=''>often</span> <span style=''>seek</span> <span style=''>to</span> <span style=''>optimize</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporating</span> <span style=''>features</span> <span style=''>that</span> <span style=''>are</span> <span style=''>not</span> <span style=''>present</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>databases</span> <span style=''>readily</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>providers</span> <span style=''>and</span> <span style=''>policy</span> <span style=''>makers</span> <span style=''>limiting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalizability</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementation</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>tested</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>of</span> <span style=''>six</span> <span style=''>month</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>mortality</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>population</span> <span style=''>of</span> <span style=''>elderly</span> <span style=''>Medicare</span> <span style=''>beneficiaries</span> <span style=''>using</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>administrative</span> <span s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12805959560127705)
# 	architecture (0.08620078041858815)
# 	segmentation (0.07307555870876198)
# 	information (0.2380276693863072)
# 	knowledge (0.13373536715147216)
# 	experimental (0.14402270308620077)
# 	detection (0.12664065271372826)
# 	different (0.26924441291238027)
# 	convolutional (0.12983327421071303)
# 	recognition (0.1376374600922313)
#
# Some Statistics words are:
# 	theoretical (0.15497223624432105)
# 	stochastic (0.1413427561837456)
# 	statistical (0.15396264512872287)
# 	variables (0.1393235739525492)
# 	estimation (0.16658253407370016)
# 	distribution (0.19384149419485108)
# 	dimensional (0.18273599192327108)
# 	inference (0.20343260979303382)
# 	algorithm (0.4139323573952549)
# 	regression (0.18374558303886926)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6a49fee1-e3d9-415f-9dbe-1c8eb7d252ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a49fee1-e3d9-415f-9dbe-1c8eb7d252ed")) {                    Plotly.newPlot(                        "6a49fee1-e3d9-415f-9dbe-1c8eb7d252ed",                        [{"x":["conditioned","relationships","observation","probabilistic","hypothesised","preserving","intrinsic","construct","distribution","introduce","intuitions","additional","variational","neighbourhood","encapsulates","embedding","observations","straightforward","optimisation","coordinates","posterior","describes","dimensionality","extensions","structure","discovery","semantics","biologically","similarities","particular","hopefully","promising","techniques","information","sufficient","ecosystem","providing","functions","capability","piecemeal","development","characteristics","adversary","biological","artificial","difficult","intelligence","communities","attributed","sophistication","integration","understand","underlying","regression","significantly","employing","processes","automatic","likelihood","statistical","automating","composition","statistician","modelling","algorithm","selection","challenging","direction","interpretable","algorithms","understood","experiments","comparable","usefulness","generative","regularizer","represented","preferable","strategies","naturally","regularization","operation","considerable","combination","applications","attention","empirical","simplicity","different","numerical","systematically","conjugate","separable","structured","components","maximization","demonstrate","homogeneous","imperfect","relaxation","infeasible","continuous","crowdsourcing","multiarmed","computation","outperforms","lagrangian","partially","tractable","observable","technique","computationally","optimality","allocation","constraints","numerically","inference","evolution","uncovering","inferring","capabilities","multivariate","performance","linguistic","evidenced","demonstrating","discussions","arguments","interaction","influence","committee","discovers","transcripts","primarily","addresses","introducing","segmented","classification","parameters","sequences","challenge","convolutional","individual","evaluated","constructed","recognition","effectively","estimates","completion","differentially","filtering","furthermore","guarantees","differential","objective","violating","revisited","consistently","preference","preferences","collaborative","empirically","reconstruct","discovering","framework","superiority","attributes","established","comparisons","integrated","traditional","exploited","corresponding","clustering","illustrate","categorical","contribution","quantitative","maximizing","localizes","connected","supervised","parameter","localizing","propagation","classifiers","optimized","localization","classifier","searching","typically","efficient","arbitrary","concentrated","important","controlled","efficiently","projected","contributes","manifests","computational","particularly","contextual","assumption","translated","hypergraph","resulting","described","independent","resultant","variables","examining","contribute","constructing","measurable","prominent","theoretical","cognitive","exploration","awareness","measurement","conditions","convenient","theoretically","developed","foundations","hypergraphs","possibility","programming","experimental","phenomena","sensitive","condition","phenomenon","associated","cognition","investigation","specification","estimation","convergence","synthetic","maximizes","extensive","outperforming","estimator","collecting","logarithmic","optimizing","unspecified","implementation","practical","available","implementing","unnecessary","efficiency","operators" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	statistician
# 	selectors
# 	confounders
# 	confounder
# 	seasonality
# 	lengthscales
# 	hermitian
# 	readmission
# 	unavoidably
# 	predictivity
# 	marginalization
# 	parametrically
# 	reversing
# 	regressive
# 	generalises
# 	applicants
# 	standardization
# 	inversions
# 	amortization
# 	presenceabsence
# Some words which never appear in Statistics papers:
# 	ecosystem
# 	piecemeal
# 	localizing
# 	unspecified
# 	megapixels
# 	photometric
# 	resistive
# 	periphery
# 	multiplexing
# 	intractability
# 	finiteness
# 	deductively
# 	propositional
# 	logically
# 	fingerprinting
# 	upsampling
# 	benefiting
# 	watershed
# 	electoral
# 	photographs

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0526894193784724e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7383333333333333
